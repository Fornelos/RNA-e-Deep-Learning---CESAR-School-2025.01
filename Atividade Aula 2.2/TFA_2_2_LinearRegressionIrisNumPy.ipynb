# %% [markdown]
# # Regressão Linear com NumPy

# %% [markdown]
# ## Objetivos deste experimento

# %% [markdown]
# Este exemplo utiliza regressão linear para estimar o comprimento das sépalas da íris a partir do seu comprimento das pétalas.
# Utiliza-se programação totalmente NumPy com:
# - o **cálculo do gradiente**,
# - a **função de perda** e
# - a atualização dos parâmetros são feitos de forma explícita.
# - A rede é criada com uma camada como uma classe

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLinear_Otimizacao.png)

# %% [markdown]
# ## Importação dos pacotes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt   # para plotting

from sklearn.datasets import load_iris  # para carregar dataset

import numpy as np  # processamento matricial

np.random.seed(1234)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Leitura dos dados

# %%
iris = load_iris()
data = iris.data[iris.target==1,::2]  # comprimento das sépalas e pétalas, indices 0 e 2

x_train = data[:,0:1]
y_train = data[:,1:2]

n_samples = x_train.shape[0]
print('x_train.shape:',x_train.shape, x_train.dtype)
print('y_train.shape:',y_train.shape, y_train.dtype)

print('x_train[:5]:\n', x_train[:5])
print('y_train[:5]:\n', y_train[:5])
# Out:
# x_train.shape: (50, 1) float64
# y_train.shape: (50, 1) float64
# x_train[:5]:
#  [[7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]]
# y_train[:5]:
#  [[4.7]
#  [4.5]
#  [4.9]
#  [4. ]
#  [4.6]]

# %% [markdown]
# ### Normalização dos dados

# %%
x_train -= x_train.min()
x_train /= x_train.max()
y_train -= y_train.min()
y_train /= y_train.max()

# %%
plt.scatter(x_train,y_train)
plt.xlabel('Comprimento sepalas')
plt.ylabel('Comprimento petalas')
# Out:
# Text(0, 0.5, 'Comprimento petalas')

# %% [markdown]
# ## Modelo da rede

# %% [markdown]
# ### Reta de ajuste

# %% [markdown]
# A equação da reta no plano necessita de dois parâmetros, aqui denominados $w_0$ (*bias*) e inclinação $w_1$. Veja figura:
#
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/linhareta.png)
#
# A reta de ajuste será dada por:
#
# $$ \hat{y} = w_0 + w_1 x $$
#
# onde
# * $w_1$ é o coeficiente angular da reta e
# * $w_0$ é a interseção do eixo vertical quando x é igual a zero, também denominado de *bias*.
# * $x$ é a variável de entrada (comprimento das sépalas) e
# * $\hat{y}$ é a predição (comprimento estimado das pétalas).

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLinearNeuronio.png)

# %% [markdown]
# ### Formulação matricial do neurônio

# %% [markdown]
# * $\mathbf{w} = [w_0 \ w_1]$ é vetor linha de parâmetros e
# * $\mathbf{x} = [1 \ x_0] $ é vetor linha de uma amostra (com *bias*).
#
# $$ \hat{y} = 1 w_0 + x_0 w_1 $$
#
# $$ [\hat{y}] = [1 \ x_0] \begin{bmatrix} w_0 \\ w_1 \end{bmatrix} $$
#
# $$ \mathbf{\hat{y}} = \mathbf{x} \mathbf{w^T} $$

# %% [markdown]
# ### Fazendo o predict de várias amostras

# %% [markdown]
# $$ \begin{matrix}
# \begin{bmatrix}
# \hat{y}_0\\
# \hat{y}_1\\
# \\
# \hat{y}_{M-1}
# \end{bmatrix} &=& \begin{bmatrix}
# 1 & x_0 \\
# 1 & x_1\\
# \\
# 1 & x_{M-1} \\
# \end{bmatrix}
# &
# \begin{bmatrix}
# w_0\\
# w_1
# \end{bmatrix} \\
# (M,1) & & (M,2) & (2,1) \\
# \end{matrix} $$

# %% [markdown]
# ### Preenchendo x com coluna de 1's para bias

# %%
x_train_bias = np.hstack([np.ones(shape=(n_samples,1)), x_train])

# %%
x_train_bias
# Out:
# array([[1.        , 1.        ],
#        [1.        , 0.71428571],
#        [1.        , 0.95238095],
#        [1.        , 0.28571429],
#        [1.        , 0.76190476],
#        [1.        , 0.38095238],
#        [1.        , 0.66666667],
#        [1.        , 0.        ],
#        [1.        , 0.80952381],
#        [1.        , 0.14285714],
#        [1.        , 0.04761905],
#        [1.        , 0.47619048],
#        [1.        , 0.52380952],
#        [1.        , 0.57142857],
#        [1.        , 0.33333333],
#        [1.        , 0.85714286],
#        [1.        , 0.33333333],
#        [1.        , 0.42857143],
#        [1.        , 0.61904762],
#        [1.        , 0.33333333],
#        [1.        , 0.47619048],
#        [1.        , 0.57142857],
#        [1.        , 0.66666667],
#        [1.        , 0.57142857],
#        [1.        , 0.71428571],
#        [1.        , 0.80952381],
#        [1.        , 0.9047619 ],
#        [1.        , 0.85714286],
#        [1.        , 0.52380952],
#        [1.        , 0.38095238],
#        [1.        , 0.28571429],
#        [1.        , 0.28571429],
#        [1.        , 0.42857143],
#        [1.        , 0.52380952],
#        [1.        , 0.23809524],
#        [1.        , 0.52380952],
#        [1.        , 0.85714286],
#        [1.        , 0.66666667],
#        [1.        , 0.33333333],
#        [1.        , 0.28571429],
#        [1.        , 0.28571429],
#        [1.        , 0.57142857],
#        [1.        , 0.42857143],
#        [1.        , 0.04761905],
#        [1.        , 0.33333333],
#        [1.        , 0.38095238],
#        [1.        , 0.38095238],
#        [1.        , 0.61904762],
#        [1.        , 0.0952381 ],
#        [1.        , 0.38095238]])

# %% [markdown]
# ### Classe com o modelo da rede

# %%
class Net():
    def __init__(self, n_in, n_out):
        self.w = np.random.uniform(-0.1,0.1,(n_out,n_in)) #inicialização dos parâmetros

    def forward(self, x_bias):
        return x_bias.dot(self.w.T)

# %% [markdown]
# ### Criando a rede, instanciando o objeto model

# %%
model = Net(2,1) # duas entradas (1 + x0) e uma saída y_pred

# %% [markdown]
# ### Testando o predict da rede (mesmo sem treiná-la)

# %%
xin = np.random.randn(4,2) # 4 amostras, 2 entradas (1 + x0)
ypred = model.forward(xin)
ypred
# Out:
# array([[-0.05100507],
#        [-0.01216805],
#        [ 0.02717522],
#        [-0.01732928]])

# %% [markdown]
# ## Treinamento via gradiente descendente

# %% [markdown]
# Função de perda:
# $$ J(\hat{y_i},y_i) = \frac{1}{M} \sum_{i=0}^{M-1} (\hat{y_i} - y_i)^2 $$

# %% [markdown]
# Gradiente:
# $$  \mathbf{\nabla{J_w}} = \frac{2}{M}\mathbf{x^T}(\mathbf{x w^T} - \mathbf{y}) $$

# %% [markdown]
# Atualização dos parâmetros pelo gradiente descendente:
# $$ \mathbf{w} = \mathbf{w} − \eta (\mathbf{\nabla J_w})^T $$

# %% [markdown]
# ### Laço de treinamento

# %%
num_epochs = 100
list_loss = []
learning_rate = 0.5
for epoch in range(num_epochs):

    # forward - predict
    y_pred = model.forward(x_train_bias)

    #loss cálculo da função de perda
    loss = np.square(y_pred - y_train).mean()
    list_loss.append(loss)

    # cálculo do gradiente pelas derivadas parciais
    w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    # gradiente descendente
    model.w = model.w - learning_rate * w_grad.T

    # verbose
    if (epoch+1) % 1 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss))
# Out:
# Epoch[1/100], loss: 0.339831
# Epoch[2/100], loss: 0.050684
# Epoch[3/100], loss: 0.031016
# Epoch[4/100], loss: 0.029003
# Epoch[5/100], loss: 0.028210
# Epoch[6/100], loss: 0.027556
# Epoch[7/100], loss: 0.026968
# Epoch[8/100], loss: 0.026434
# Epoch[9/100], loss: 0.025949
# Epoch[10/100], loss: 0.025509
# Epoch[11/100], loss: 0.025109
# Epoch[12/100], loss: 0.024746
# Epoch[13/100], loss: 0.024417
# Epoch[14/100], loss: 0.024118
# Epoch[15/100], loss: 0.023846
# Epoch[16/100], loss: 0.023600
# Epoch[17/100], loss: 0.023376
# Epoch[18/100], loss: 0.023173
# Epoch[19/100], loss: 0.022988
# Epoch[20/100], loss: 0.022821
# Epoch[21/100], loss: 0.022669
# Epoch[22/100], loss: 0.022531
# Epoch[23/100], loss: 0.022405
# Epoch[24/100], loss: 0.022291
# Epoch[25/100], loss: 0.022188
# Epoch[26/100], loss: 0.022094
# Epoch[27/100], loss: 0.022009
# Epoch[28/100], loss: 0.021932
# Epoch[29/100], loss: 0.021862
# Epoch[30/100], loss: 0.021798
# Epoch[31/100], loss: 0.021740
# Epoch[32/100], loss: 0.021687
# Epoch[33/100], loss: 0.021640
# Epoch[34/100], loss: 0.021596
# Epoch[35/100], loss: 0.021557
# Epoch[36/100], loss: 0.021521
# Epoch[37/100], loss: 0.021489
# Epoch[38/100], loss: 0.021460
# Epoch[39/100], loss: 0.021433
# Epoch[40/100], loss: 0.021409
# Epoch[41/100], loss: 0.021387
# Epoch[42/100], loss: 0.021367
# Epoch[43/100], loss: 0.021348
# Epoch[44/100], loss: 0.021332
# Epoch[45/100], loss: 0.021317
# Epoch[46/100], loss: 0.021303
# Epoch[47/100], loss: 0.021291
# Epoch[48/100], loss: 0.021280
# Epoch[49/100], loss: 0.021270
# Epoch[50/100], loss: 0.021260
# Epoch[51/100], loss: 0.021252
# Epoch[52/100], loss: 0.021244
# Epoch[53/100], loss: 0.021238
# Epoch[54/100], loss: 0.021231
# Epoch[55/100], loss: 0.021226
# Epoch[56/100], loss: 0.021220
# Epoch[57/100], loss: 0.021216
# Epoch[58/100], loss: 0.021211
# Epoch[59/100], loss: 0.021208
# Epoch[60/100], loss: 0.021204
# Epoch[61/100], loss: 0.021201
# Epoch[62/100], loss: 0.021198
# Epoch[63/100], loss: 0.021195
# Epoch[64/100], loss: 0.021193
# Epoch[65/100], loss: 0.021191
# Epoch[66/100], loss: 0.021189
# Epoch[67/100], loss: 0.021187
# Epoch[68/100], loss: 0.021185
# Epoch[69/100], loss: 0.021184
# Epoch[70/100], loss: 0.021183
# Epoch[71/100], loss: 0.021181
# Epoch[72/100], loss: 0.021180
# Epoch[73/100], loss: 0.021179
# Epoch[74/100], loss: 0.021178
# Epoch[75/100], loss: 0.021178
# Epoch[76/100], loss: 0.021177
# Epoch[77/100], loss: 0.021176
# Epoch[78/100], loss: 0.021176
# Epoch[79/100], loss: 0.021175
# Epoch[80/100], loss: 0.021174
# Epoch[81/100], loss: 0.021174
# Epoch[82/100], loss: 0.021174
# Epoch[83/100], loss: 0.021173
# Epoch[84/100], loss: 0.021173
# Epoch[85/100], loss: 0.021173
# Epoch[86/100], loss: 0.021172
# Epoch[87/100], loss: 0.021172
# Epoch[88/100], loss: 0.021172
# Epoch[89/100], loss: 0.021172
# Epoch[90/100], loss: 0.021171
# Epoch[91/100], loss: 0.021171
# Epoch[92/100], loss: 0.021171
# Epoch[93/100], loss: 0.021171
# Epoch[94/100], loss: 0.021171
# Epoch[95/100], loss: 0.021171
# Epoch[96/100], loss: 0.021170
# Epoch[97/100], loss: 0.021170
# Epoch[98/100], loss: 0.021170
# Epoch[99/100], loss: 0.021170
# Epoch[100/100], loss: 0.021170

# %% [markdown]
# ## Avaliação

# %% [markdown]
# ### Predict

# %%
y_pred = model.forward(x_train_bias)
plt.plot(x_train, y_train, 'ro', label='Original data')
plt.plot(x_train, y_pred, 'kx-', label='Fitting Line')

# %% [markdown]
# ### Parâmetros treinados

# %%
print(model.w)
# Out:
# [[0.26306045 0.68314988]]

# %% [markdown]
# ### Avaliação do modelo

# %%
loss = np.square(y_pred - y_train).mean()
loss
# Out:
# np.float64(0.02117008324736041)

# %% [markdown]
# ### Valor ótimo, solução analítica

# %% [markdown]
# $$  \mathbf{w} =(\mathbf{x^T} \mathbf{x})^{−1}\mathbf{x^T} \mathbf{y} $$

# %%
x = x_train_bias
y = y_train
w_opt = (np.linalg.inv((x.T).dot(x)).dot(x.T)).dot(y)
print(w_opt.T)
# Out:
# [[0.26134159 0.68646976]]

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## Questões

# %% [markdown]
# 1. Quantos parâmetros são treinados nesse modelo?
# R - 2 parametros w0 e w1 os pesos.
#
# 2. Qual é o número de atributos de entrada para a rede?
# R - 1 x comprimento da sepala
#
# 3. Qual é o número de saídas da rede?
# R - 1 ypred comprimento da petala
#
# 4. Suponha que eu tenha agora 5 mil amostras para fazer a predição. Qual é o shape da matriz de entrada?
# R - [5k,2]
# Qual é o shape do matriz de saída?
# R - [5k,1]

# %% [markdown]
# ## Atividades

# %% [markdown]
# 1. Modifique o laço do treinamento via gradiente descendente para guardar em uma lista, o valor da perda no final
#    de cada época. Após o treinamento, plote o valor da perda em função da época.
# 2. Calcule o valor da perda (MSE) da rede com os parâmetros inicializados, sem serem treinados.
# 3. Coloque os valores dos pesos da solução ótima analítica no modelo da rede e calcule o valor da perda (MSE) e
#    compare com o valor da perda obtida pelo método da otimização via gradiente descendente.

# %% [markdown]
# # Aprendizados

# %%
list_loss
# Out:
# [np.float64(0.3398312818108879),
#  np.float64(0.05068370223997065),
#  np.float64(0.031015827060072002),
#  np.float64(0.029003172448040945),
#  np.float64(0.028209553508144164),
#  np.float64(0.027556463693871557),
#  np.float64(0.026967922014914967),
#  np.float64(0.02643387098874793),
#  np.float64(0.02594902380718811),
#  np.float64(0.025508831381129093),
#  np.float64(0.025109179947633623),
#  np.float64(0.02474633568133725),
#  np.float64(0.02441690870497431),
#  np.float64(0.024117821347284824),
#  np.float64(0.023846279385167923),
#  np.float64(0.023599745938350677),
#  np.float64(0.023375917768568746),
#  np.float64(0.02317270376156602),
#  np.float64(0.02298820539086344),
#  np.float64(0.022820698980778986),
#  np.float64(0.02266861960299079),
#  np.float64(0.02253054645619729),
#  np.float64(0.022405189592283686),
#  np.float64(0.022291377864984138),
#  np.float64(0.022188047988449925),
#  np.float64(0.022094234603503463),
#  np.float64(0.022009061258771955),
#  np.float64(0.02193173222244208),
#  np.float64(0.021861525048137057),
#  np.float64(0.02179778382546271),
#  np.float64(0.021739913052165816),
#  np.float64(0.021687372070655467),
#  np.float64(0.0216396700169105),
#  np.float64(0.021596361234583333),
#  np.float64(0.021557041111456354),
#  np.float64(0.021521342299353027),
#  np.float64(0.02148893128218829),
#  np.float64(0.021459505260095105),
#  np.float64(0.021432789320517297),
#  np.float64(0.02140853386983948),
#  np.float64(0.021386512301559232),
#  np.float64(0.021366518879216215),
#  np.float64(0.02134836681429973),
#  np.float64(0.021331886521177342),
#  np.float64(0.021316924032741488),
#  np.float64(0.021303339561972036),
#  np.float64(0.021291006195976327),
#  np.float64(0.02127980871030568),
#  np.float64(0.021269642492471236),
#  np.float64(0.021260412564601962),
#  np.float64(0.021252032696114052),
#  np.float64(0.02124442459810189),
#  np.float64(0.021237517191924068),
#  np.float64(0.021231245945151345),
#  np.float64(0.02122555226867251),
#  np.float64(0.021220382969325744),
#  np.float64(0.0212156897529416),
#  np.float64(0.02121142877315483),
#  np.float64(0.02120756022176975),
#  np.float64(0.021204047956852327),
#  np.float64(0.021200859165074148),
#  np.float64(0.021197964055154013),
#  np.float64(0.02119533557953293),
#  np.float64(0.021192949181682335),
#  np.float64(0.021190782566684795),
#  np.float64(0.021188815492943755),
#  np.float64(0.021187029583076486),
#  np.float64(0.02118540815222341),
#  np.float64(0.02118393605216981),
#  np.float64(0.02118259952982371),
#  np.float64(0.021181386098727596),
#  np.float64(0.02118028442240373),
#  np.float64(0.02117928420844312),
#  np.float64(0.021178376112348723),
#  np.float64(0.02117755165023448),
#  np.float64(0.021176803119564633),
#  np.float64(0.0211761235271928),
#  np.float64(0.021175506524028536),
#  np.float64(0.02117494634572092),
#  np.float64(0.02117443775880518),
#  np.float64(0.021173976011808995),
#  np.float64(0.021173556790861938),
#  np.float64(0.021173176179393082),
#  np.float64(0.0211728306215405),
#  np.float64(0.021172516888930598),
#  np.float64(0.02117223205051706),
#  np.float64(0.02117197344519755),
#  np.float64(0.02117173865695234),
#  np.float64(0.021171525492272705),
#  np.float64(0.021171331959668013),
#  np.float64(0.02117115625106028),
#  np.float64(0.021170996724892154),
#  np.float64(0.02117085189079073),
#  np.float64(0.021170720395643668),
#  np.float64(0.0211706010109578),
#  np.float64(0.021170492621381935),
#  np.float64(0.021170394214286667),
#  np.float64(0.021170304870303882),
#  np.float64(0.02117022375473759),
#  np.float64(0.02117015010976577)]

# %% [markdown]
# Questão 1:

# %%
plt.figure(figsize=(12, 7))
plt.plot(list_loss, label='Perda (Loss)', color='blue')
plt.title('Curva de Perda ao Longo dos epocas/Iterações', fontsize=16)
plt.xlabel('Epocas', fontsize=14)
plt.ylabel('Valor da Perda', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# %% [markdown]
# Questão 2: Perda (MSE) da rede com os parâmetros inicializados, sem serem treinados.
#
# Função de perda:
# $$ J(\hat{y_i},y_i) = \frac{1}{M} \sum_{i=0}^{M-1} (\hat{y_i} - y_i)^2 $$

# %%
model = Net(2,1)

# %%
ypred = model.forward(x_train_bias)

# %%
#loss cálculo da função de perda
perda = np.square(ypred - y_train).mean()
perda
# Out:
# np.float64(0.5382612343347966)

# %% [markdown]
# Questão 3:
# ### Valor ótimo, solução analítica
# $$  \mathbf{w} =(\mathbf{x^T} \mathbf{x})^{−1}\mathbf{x^T} \mathbf{y} $$

# %%
x = x_train_bias
y = y_train
w_opt = (np.linalg.inv((x.T).dot(x)).dot(x.T)).dot(y)
w_opt.T
# Out:
# array([[0.26134159, 0.68646976]])

# %%
class Net_new():
    def __init__(self, n_in, n_out):
      if w_opt.T is not None:
            # Atribui o peso ótimo
            self.w = w_opt.T
      else:
        self.w = np.random.uniform(-0.1,0.1,(n_out,n_in)) #inicialização dos parâmetros

    def forward(self, x_bias):
        return x_bias.dot(self.w.T)

# %%
model = Net_new(2,1)

# %%
num_epochs = 100
learning_rate = 0.5
for epoch in range(num_epochs):

    # forward - predict
    y_pred = model.forward(x_train_bias)

    #loss cálculo da função de perda
    loss_opt = np.square(y_pred - y_train).mean()

    # cálculo do gradiente pelas derivadas parciais
    w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    # gradiente descendente
    model.w = model.w - learning_rate * w_grad.T

# %%
model.w
# Out:
# array([[0.26134159, 0.68646976]])

# %%
# Perda com Pesos Otimos
loss_opt
# Out:
# np.float64(0.02116942411909716)

# %%
# Perda obtida pelo método da otimização via gradiente descendente.
loss
# Out:
# np.float64(0.02117008324736041)
