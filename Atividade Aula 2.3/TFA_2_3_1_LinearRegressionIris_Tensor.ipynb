# %% [markdown]
# # Exercício Regressão Linear com PyTorch

# %% [markdown]
# O objetivo desse notebook é reescrevê-lo porém utilizando tensores do PyTorch.
#
# Os nomes das funções do PyTorch são próximas das funções do Torch original escrito
# na linguagem Lua, porém não são iguais.

# %% [markdown]
# ## Importação dos pacotes

# %%
# %matplotlib inline
import torch
from torch import nn, optim
import numpy as np

import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

torch.manual_seed(1234)

def print_assert(r):
    if r:
        return 'OK!'
    else:
        return 'Incorreto!'

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Leitura dos dados

# %%
import pandas as pd
iris = load_iris()
data = iris.data[iris.target==1,::2]  # comprimento das sépalas e pétalas, indices 0 e 2

x_in = data[:,0:1]
y_in = data[:,1:2]

x_train = torch.FloatTensor(x_in)
y_train = torch.FloatTensor(y_in)

n_samples = x_train.size(0)
print('x_train.shape:',x_train.shape, type(x_train))
print('y_train.shape:',y_train.shape, type(y_train))

print('x_train[:5]:\n', x_train[:5])
print('y_train[:5]:\n', y_train[:5])

iris_pd = pd.DataFrame(x_in, columns=['x_in'])
iris_pd['y_in'] = y_in
iris_pd.head()
# Out:
# x_train.shape: torch.Size([50, 1]) <class 'torch.Tensor'>
# y_train.shape: torch.Size([50, 1]) <class 'torch.Tensor'>
# x_train[:5]:
#  tensor([[7.0000],
#         [6.4000],
#         [6.9000],
#         [5.5000],
#         [6.5000]])
# y_train[:5]:
#  tensor([[4.7000],
#         [4.5000],
#         [4.9000],
#         [4.0000],
#         [4.6000]])
#    x_in  y_in
# 0   7.0   4.7
# 1   6.4   4.5
# 2   6.9   4.9
# 3   5.5   4.0
# 4   6.5   4.6

# %% [markdown]
# ### Normalização dos dados

# %%
x_train -= x_train.min()
x_train /= x_train.max()
y_train -= y_train.min()
y_train /= y_train.max()

plt.scatter(x_train,y_train)
plt.xlabel('Comprimento sepalas')
plt.ylabel('Comprimento petalas')
# Out:
# Text(0, 0.5, 'Comprimento petalas')

# %% [markdown]
# ### Exercício 1 - Criação do `x_train_bias`

# %% [markdown]
# faça o `x_train_bias` ser uma matriz com 1s na primeira coluna e x_train na segunda coluna.
#
#
#
#
# Dica: você pode precisar da função [torch.cat](http://pytorch.org/docs/master/torch.html#torch.cat) e [torch.ones](http://pytorch.org/docs/master/torch.html#torch.ones).

# %%
# TODO
bias = torch.ones(x_train.shape[0], 1)
x_train_bias = torch.cat([bias,x], dim=1)
x_train_bias
# Out:
# tensor([[1.0000, 1.0000],
#         [1.0000, 0.7143],
#         [1.0000, 0.9524],
#         [1.0000, 0.2857],
#         [1.0000, 0.7619],
#         [1.0000, 0.3810],
#         [1.0000, 0.6667],
#         [1.0000, 0.0000],
#         [1.0000, 0.8095],
#         [1.0000, 0.1429],
#         [1.0000, 0.0476],
#         [1.0000, 0.4762],
#         [1.0000, 0.5238],
#         [1.0000, 0.5714],
#         [1.0000, 0.3333],
#         [1.0000, 0.8571],
#         [1.0000, 0.3333],
#         [1.0000, 0.4286],
#         [1.0000, 0.6190],
#         [1.0000, 0.3333],
#         [1.0000, 0.4762],
#         [1.0000, 0.5714],
#         [1.0000, 0.6667],
#         [1.0000, 0.5714],
#         [1.0000, 0.7143],
#         [1.0000, 0.8095],
#         [1.0000, 0.9048],
#         [1.0000, 0.8571],
#         [1.0000, 0.5238],
#         [1.0000, 0.3810],
#         [1.0000, 0.2857],
#         [1.0000, 0.2857],
#         [1.0000, 0.4286],
#         [1.0000, 0.5238],
#         [1.0000, 0.2381],
# ...

# %%
# Verificação do exercício - Execute para testar sua implementação

print('x_train_bias é um tensor: {}'.format(print_assert(
    isinstance(x_train_bias, torch.FloatTensor)
)))

print('tamanho do x_train_bias: {}'.format(print_assert(
    x_train_bias.size() == torch.Size([50, 2])
)))

print('primeira coluna é só de uns: {}'.format(print_assert(
    (x_train_bias[:, 0] - torch.ones(n_samples)).sum() == 0
)))

print('segunda coluna é igual a x_train: {}'.format(print_assert(
    (x_train_bias[:, 1] - x_train.reshape(50)).sum() == 0
)))
# Out:
# x_train_bias é um tensor: OK!
# tamanho do x_train_bias: OK!
# primeira coluna é só de uns: OK!
# segunda coluna é igual a x_train: OK!

# %% [markdown]
# ## Modelo da rede

# %% [markdown]
# ### Definição da classe

# %%
class Net():
    def __init__(self, n_in, n_out):
        self.w = torch.Tensor(n_out, n_in)
        self.w.uniform_(-0.1,0.1) #inicialização dos parâmetros

    def forward(self, x_bias):
        return x_bias.matmul(torch.t(self.w))

# %% [markdown]
# ### Instanciando a rede

# %%
model = Net(2,1)

# %% [markdown]
# ### Testando o predict da rede

# %%
model.forward(torch.ones((4,2)))
#model.forward(torch.randn(4,2))
# Out:
# tensor([[-0.1138],
#         [-0.1138],
#         [-0.1138],
#         [-0.1138]])

# %% [markdown]
# ## Treinamento

# %% [markdown]
# ### Exercício 2 - Treinamento

# %% [markdown]
# Refaça o código de treinamento da rede, mas agora utilizando somente Tensores do PyTorch. Faça o mesmo procedimento que o notebook [LinearRegressionIrisNumPy](LinearRegressionIrisNumPy.ipynb). Para consultar as operações disponíveis no PyTorch use a [documentação do PyTorch](http://pytorch.org/docs/master/torch.html).
#
# Funções que podem ser úteis:
# - torch.t
# - torch.mean
# - torch.matmul

# %%
num_epochs = 100
learning_rate = 0.5
for epoch in range(num_epochs):

    # forward - predict
    y_pred = model.forward(x_train_bias)

    #loss cálculo da função de perda
    #loss_old = np.square(y_pred - y_train).mean()
    # TODO
    loss = torch.mean((y_pred - y_train)**2)
    #print('loss com PyTorch: {:.6f}'.format(loss))

    # cálculo do gradiente pelas derivadas parciais
    #w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    # TODO
    x_train_bias_t = torch.t(x_train_bias)
    model_w_t = torch.t(model.w)
    y_train_t = torch.t(y_train)
    x_y = torch.matmul(x_train_bias, model_w_t)
    w_grad = (2.0/n_samples) * torch.matmul(x_train_bias_t, x_y - y_train)


    # gradiente descendente
    #model.w = model.w - learning_rate * w_grad.T
    # TODO
    model.w = model.w - learning_rate * w_grad.T

    # verbose
    if (epoch+1) % 1 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss))
# Out:
# Epoch[1/100], loss: 0.021171
# Epoch[2/100], loss: 0.021171
# Epoch[3/100], loss: 0.021171
# Epoch[4/100], loss: 0.021171
# Epoch[5/100], loss: 0.021171
# Epoch[6/100], loss: 0.021171
# Epoch[7/100], loss: 0.021170
# Epoch[8/100], loss: 0.021170
# Epoch[9/100], loss: 0.021170
# Epoch[10/100], loss: 0.021170
# Epoch[11/100], loss: 0.021170
# Epoch[12/100], loss: 0.021170
# Epoch[13/100], loss: 0.021170
# Epoch[14/100], loss: 0.021170
# Epoch[15/100], loss: 0.021170
# Epoch[16/100], loss: 0.021170
# Epoch[17/100], loss: 0.021170
# Epoch[18/100], loss: 0.021170
# Epoch[19/100], loss: 0.021170
# Epoch[20/100], loss: 0.021170
# Epoch[21/100], loss: 0.021170
# Epoch[22/100], loss: 0.021170
# Epoch[23/100], loss: 0.021170
# Epoch[24/100], loss: 0.021170
# Epoch[25/100], loss: 0.021170
# Epoch[26/100], loss: 0.021170
# Epoch[27/100], loss: 0.021170
# Epoch[28/100], loss: 0.021170
# Epoch[29/100], loss: 0.021170
# Epoch[30/100], loss: 0.021170
# Epoch[31/100], loss: 0.021170
# ...

# %% [markdown]
# ## Avaliação

# %% [markdown]
# ### Predict

# %%
y_pred = model.forward(x_train_bias)
plt.plot(x_train.numpy(), y_train.numpy(), 'ro', label='Original data')
plt.plot(x_train.numpy(), y_pred.numpy(), 'kx-', label='Fitting Line')
plt.show()

# %% [markdown]
# ### Parâmetro treinado

# %%
print(model.w)
# Out:
# tensor([[0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
#         [0.2614, 0.6864],
# ...

# %%
x_bias = x_train_bias
y = y_train
w_opt = (torch.inverse(x_bias.t().mm(x_bias)).mm(x_bias.t())).mm(y)
print(w_opt.t())
# Out:
# tensor([[0.2613, 0.6865]])
